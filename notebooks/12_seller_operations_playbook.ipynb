# %% [markdown]
# # 12 Seller Operations Playbook
#
# This notebook converts seller risk monitoring into an action queue with owners, SLA, and success metrics.

# %%
from src.seller_operations_playbook import main

main()
