# %% [markdown]
# # 13 Intervention Experiment Design
#
# This notebook defines a controlled experiment plan for validating risk-based customer interventions.

# %%
from src.intervention_experiment_design import main

main()
