# %% [markdown]
# # 11 Root-Cause Decomposition
#
# This notebook turns customer-experience analysis into contribution-based root-cause diagnosis.

# %%
from src.root_cause_decomposition import main

main()
